# %%
'''
2]hearing_test.csv
'''

# %% [markdown]
# # CLASSFICATION

# %% [markdown]
# ### PROBLEM DEFINATION
#  -hearing test result

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### READ THE DATA

# %%
df = pd.read_csv("F:\\GIT DBDA - SUNBEAM\\Machine Learning\\practical_machine_learning\\assignment\\hearing_test.csv")
print(df)
# Out:
#        age  physical_score  test_result
# 0     33.0            40.7            1
# 1     50.0            37.2            1
# 2     52.0            24.7            0
# 3     56.0            31.0            0
# 4     35.0            42.9            1
# ...    ...             ...          ...
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1
#
# [5000 rows x 3 columns]

# %% [markdown]
# ### EDA

# %%
# CHECK ISNA
df.isna().sum()
# Out:
# age               0
# physical_score    0
# test_result       0
# dtype: int64

# %%
#check cov 
df.cov()
# Out:
#                        age  physical_score  test_result
# age             127.396398      -72.123723    -3.777956
# physical_score  -72.123723       66.745660     3.173059
# test_result      -3.777956        3.173059     0.240048

# %%
# column names
df.columns
# Out:
# Index(['age', 'physical_score', 'test_result'], dtype='object')

# %%
#check corr
df.corr()['test_result']
# Out:
# age              -0.683171
# physical_score    0.792716
# test_result       1.000000
# Name: test_result, dtype: float64

# %%
sns.pairplot(df)

# %% [markdown]
# ### select dependent and independent variables

# %%
x = df.drop(['age', 'test_result'], axis=1)
y = df['test_result']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.8)

# %%
from sklearn.linear_model import LogisticRegressionCV
model = LogisticRegressionCV()
model.fit(x_train, y_train)
# Out:
# LogisticRegressionCV()

# %% [markdown]
# ### MODEL EVALUATION

# %%
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[348,  53],
#        [ 26, 573]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_predict)
accuracy
# Out:
# 0.921
